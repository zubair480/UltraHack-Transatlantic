# %%
import tensorflow

# %%
#!unzip "/content/drive/MyDrive/YoloV8 UltraHack Hackathon/Data-20230422T163013Z-001.zip" -d "/content/drive/MyDrive/YoloV8 UltraHack Hackathon/"

# %%
import os 
os.getcwd()
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/YoloV8 UltraHack Hackathon
# Out:
# /content/drive/MyDrive/YoloV8 UltraHack Hackathon

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 21.7 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 154MB/s]

# %%
# !touch data.yamal

# %%
model.train(data = "/content/drive/MyDrive/YoloV8 UltraHack Hackathon/data.yamal", epochs = 50) # Fine Tune the model/content/drive/MyDrive/Yolov8 UltraHack Hackathon/data.yamal
# Out:
# Ultralytics YOLOv8.0.84 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/drive/MyDrive/YoloV8 UltraHack Hackathon/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/YoloV8 UltraHack Hackathon/Japan and Koreas Amazing Modern Bridge Building Technology. Heavy Duty Construction Equipments.mp4", save = True, save_txt = True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1500) /content/drive/MyDrive/YoloV8 UltraHack Hackathon/Japan and Koreas Amazing Modern Bridge Building Technology. Heavy Duty Construction Equipments.mp4: 384x640 3 persons, 67.6ms
# video 1/1 (2/1500) /content/drive/MyDrive/YoloV8 UltraHack Hackathon/Japan and Koreas Amazing Modern Bridge Building Technology. Heavy Duty Construction Equipments.mp4: 384x640 3 persons, 25.9ms
# ...
